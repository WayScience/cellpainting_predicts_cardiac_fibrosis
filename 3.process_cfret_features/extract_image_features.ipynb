# %% [markdown]
# # Process image features from CellProfiler readout - Only Factin_Adjusted
#
# After discussion, we want to look into the Factin_Adjusted plate as it contains the better protocols for the actin channel so we are more interested in this data.
# In this notebook, we create two different CSV outputs, one with the image features (e.g., Granularity, Texture, etc.) and one for the image quality metrics (e.g. blur).

# %% [markdown]
# ## Import Libraries

# %%
import pathlib
import pandas as pd

from pycytominer import annotate
from pycytominer.cyto_utils import output

import sys
sys.path.append("../../utils")
import extraction_utils as extract_utils

# %% [markdown]
# ## Set up paths to CellProfiler directory and outputs

# %%
# Set file and directory constants
cp_dir = "../2.cellprofiler_processing"
output_dir = "data"

# %% [markdown]
# ## Set paths to sqlite files

# %%
# Set name and path of .sqlite file and path to metadata
sql_file = "localhost220513100001_KK22-05-198_FactinAdjusted.sqlite"
single_cell_file = f"sqlite:///{cp_dir}/CellProfiler_output/{sql_file}"
# plate_2 is synonymous with the Factin_Adjusted plate
platemap_file = "metadata/plate_2_CFReT.csv"
image_table_name = "Per_Image"

# Set paths with name for outputted data
image_quality_output_file = pathlib.Path(f"{output_dir}/image_quality_Factin_Adjusted.csv.gz")
image_features_output_file = pathlib.Path(f"{output_dir}/image_features_Factin_Adjusted.csv.gz")

# %% [markdown]
# ## Set variables for extracting image measurements

# %%
# These image feature categories are based on the measurement modules ran in the CellProfiler pipeline 
# Texture not included as it was added post running the plate originally
image_feature_categories = ["Image_Correlation", "Image_Granularity", "Image_Intensity", "Image_Texture"]
image_quality_category = ["Image_ImageQuality"]
image_cols=["ImageNumber", "Image_Count_Cells", "Image_Count_Cytoplasm", "Image_Count_Nuclei"]
strata=["Image_Metadata_Well", "Image_Metadata_Plate"]

# %% [markdown]
# ## Load and view platemap file

# %%
# Load platemap file
platemap_df = pd.read_csv(platemap_file)
platemap_df.head()
# Out:
#   WellRow  WellCol well_position  heart_number treatment  dose
# 0       A        9           A09             9    drug_x   5uM
# 1       A       10           A10             9    drug_x  10uM
# 2       A       11           A11             9    drug_x  10uM
# 3       A       12           A12             9      DMSO   0uM
# 4       B        9           B09             9    drug_x   5uM

# %% [markdown]
# ## Load in sqlite file

# %%
image_df = extract_utils.load_sqlite_as_df(single_cell_file, image_table_name)

print(image_df.shape)
image_df.head()
# Out:
# (512, 614)
#    ImageNumber  Image_Correlation_Correlation_Actin_ER  \
# 0            1                                0.319439
# 1            2                                0.316284
# 2            3                                0.424681
# 3            4                                0.254302
# 4            5                                0.223079
#
#    Image_Correlation_Correlation_Actin_Golgi  \
# 0                                   0.321517
# 1                                   0.453749
# 2                                   0.416474
# 3                                   0.232419
# 4                                   0.265874
#
#    Image_Correlation_Correlation_Actin_Hoechst  \
# 0                                     0.085523
# 1                                     0.145243
# 2                                     0.167123
# 3                                     0.038660
# 4                                     0.035197
#
#    Image_Correlation_Correlation_Actin_Mitochondria  \
# 0                                          0.383154
# 1                                          0.434937
# 2                                          0.467472
# 3                                          0.296697
# 4                                          0.308074
#
#    Image_Correlation_Correlation_ER_Golgi  \
# 0                                0.857580
# 1                                0.855621
# 2                                0.925546
# 3                                0.868859
# 4                                0.900860
#
#    Image_Correlation_Correlation_ER_Hoechst  \
# 0                                  0.359548
# 1                                  0.458719
# 2                                  0.507574
# 3                                  0.475344
# 4                                  0.329486
#
#    Image_Correlation_Correlation_ER_Mitochondria  \
# 0                                       0.844906
# 1                                       0.866483
# 2                                       0.935513
# 3                                       0.893075
# 4                                       0.895757
#
#    Image_Correlation_Correlation_Golgi_Hoechst  \
# 0                                     0.629203
# 1                                     0.690948
# 2                                     0.668837
# 3                                     0.724819
# 4                                     0.560036
#
#    Image_Correlation_Correlation_Golgi_Mitochondria  ...  \
# 0                                          0.916118  ...
# 1                                          0.913332  ...
# 2                                          0.943327  ...
# 3                                          0.920282  ...
# 4                                          0.941737  ...
#
#                                      Image_URL_Actin  \
# 0  file:/home/jenna/CFReT_data/1.preprocessing-da...
# 1  file:/home/jenna/CFReT_data/1.preprocessing-da...
# 2  file:/home/jenna/CFReT_data/1.preprocessing-da...
# 3  file:/home/jenna/CFReT_data/1.preprocessing-da...
# 4  file:/home/jenna/CFReT_data/1.preprocessing-da...
#
#                                         Image_URL_ER  \
# 0  file:/home/jenna/CFReT_data/1.preprocessing-da...
# 1  file:/home/jenna/CFReT_data/1.preprocessing-da...
# 2  file:/home/jenna/CFReT_data/1.preprocessing-da...
# 3  file:/home/jenna/CFReT_data/1.preprocessing-da...
# 4  file:/home/jenna/CFReT_data/1.preprocessing-da...
#
#                                      Image_URL_Golgi  \
# 0  file:/home/jenna/CFReT_data/1.preprocessing-da...
# 1  file:/home/jenna/CFReT_data/1.preprocessing-da...
# 2  file:/home/jenna/CFReT_data/1.preprocessing-da...
# 3  file:/home/jenna/CFReT_data/1.preprocessing-da...
# 4  file:/home/jenna/CFReT_data/1.preprocessing-da...
#
#                                    Image_URL_Hoechst  \
# 0  file:/home/jenna/CFReT_data/1.preprocessing-da...
# 1  file:/home/jenna/CFReT_data/1.preprocessing-da...
# 2  file:/home/jenna/CFReT_data/1.preprocessing-da...
# 3  file:/home/jenna/CFReT_data/1.preprocessing-da...
# 4  file:/home/jenna/CFReT_data/1.preprocessing-da...
#
#                               Image_URL_Mitochondria  Image_Width_Actin  \
# 0  file:/home/jenna/CFReT_data/1.preprocessing-da...               1104
# 1  file:/home/jenna/CFReT_data/1.preprocessing-da...               1104
# 2  file:/home/jenna/CFReT_data/1.preprocessing-da...               1104
# 3  file:/home/jenna/CFReT_data/1.preprocessing-da...               1104
# 4  file:/home/jenna/CFReT_data/1.preprocessing-da...               1104
#
#    Image_Width_ER  Image_Width_Golgi  Image_Width_Hoechst  \
# 0            1104               1104                 1104
# 1            1104               1104                 1104
# 2            1104               1104                 1104
# 3            1104               1104                 1104
# 4            1104               1104                 1104
#
#    Image_Width_Mitochondria
# 0                      1104
# 1                      1104
# 2                      1104
# 3                      1104
# 4                      1104
#
# [5 rows x 614 columns]

# %% [markdown]
# ## Extract image features from sqlite file

# %%
image_features_df = extract_utils.extract_image_features(image_feature_categories, image_df, image_cols, strata)

print(image_features_df.shape)
image_features_df.head()
# Out:
# (512, 511)
#    ImageNumber  Image_Count_Cells  Image_Count_Cytoplasm  Image_Count_Nuclei  \
# 0            1                 34                     34                  44
# 1            2                 23                     23                  37
# 2            3                 16                     16                  25
# 3            4                 30                     30                  44
# 4            5                 20                     20                  29
#
#     Image_Metadata_Plate Image_Metadata_Well  \
# 0  localhost220513100001                 A09
# 1  localhost220513100001                 A09
# 2  localhost220513100001                 A09
# 3  localhost220513100001                 A09
# 4  localhost220513100001                 A09
#
#    Image_Correlation_Correlation_Actin_ER  \
# 0                                0.319439
# 1                                0.316284
# 2                                0.424681
# 3                                0.254302
# 4                                0.223079
#
#    Image_Correlation_Correlation_Actin_Golgi  \
# 0                                   0.321517
# 1                                   0.453749
# 2                                   0.416474
# 3                                   0.232419
# 4                                   0.265874
#
#    Image_Correlation_Correlation_Actin_Hoechst  \
# 0                                     0.085523
# 1                                     0.145243
# 2                                     0.167123
# 3                                     0.038660
# 4                                     0.035197
#
#    Image_Correlation_Correlation_Actin_Mitochondria  ...  \
# 0                                          0.383154  ...
# 1                                          0.434937  ...
# 2                                          0.467472  ...
# 3                                          0.296697  ...
# 4                                          0.308074  ...
#
#    Image_Texture_Variance_Golgi_3_02_256  \
# 0                              52.706348
# 1                              38.904857
# 2                              38.207461
# 3                              50.203604
# 4                              64.981442
#
#    Image_Texture_Variance_Golgi_3_03_256  \
# 0                              52.749870
# 1                              38.935283
# 2                              38.226081
# 3                              50.256349
# 4                              65.074773
#
#    Image_Texture_Variance_Hoechst_3_00_256  \
# 0                                91.719909
# 1                                60.510194
# 2                                38.139204
# 3                               106.297290
# 4                                56.298831
#
#    Image_Texture_Variance_Hoechst_3_01_256  \
# 0                                91.543430
# 1                                60.549699
# 2                                38.106845
# 3                               106.425268
# 4                                56.222616
#
#    Image_Texture_Variance_Hoechst_3_02_256  \
# 0                                91.470904
# 1                                60.527953
# 2                                38.133159
# 3                               106.365254
# 4                                56.305175
#
#    Image_Texture_Variance_Hoechst_3_03_256  \
# 0                                91.541820
# 1                                60.549702
# 2                                38.106841
# 3                               106.430593
# 4                                56.218610
#
#    Image_Texture_Variance_Mitochondria_3_00_256  \
# 0                                     65.783776
# 1                                     44.818650
# 2                                     50.200080
# 3                                     56.979249
# 4                                     93.277867
#
#    Image_Texture_Variance_Mitochondria_3_01_256  \
# 0                                     65.846346
# 1                                     44.846460
# 2                                     50.285655
# 3                                     57.034142
# 4                                     93.388141
#
#    Image_Texture_Variance_Mitochondria_3_02_256  \
# 0                                     65.777592
# 1                                     44.806184
# 2                                     50.230629
# 3                                     56.989758
# 4                                     93.274971
#
#    Image_Texture_Variance_Mitochondria_3_03_256
# 0                                     65.846211
# 1                                     44.846421
# 2                                     50.285723
# 3                                     57.034399
# 4                                     93.388373
#
# [5 rows x 511 columns]

# %% [markdown]
# ## Extract image quality from sqlite file

# %%
image_quality_df = extract_utils.extract_image_features(image_quality_category, image_df, image_cols, strata)

print(image_quality_df.shape)
image_quality_df.head()
# Out:
# (512, 31)
#    ImageNumber  Image_Count_Cells  Image_Count_Cytoplasm  Image_Count_Nuclei  \
# 0            1                 34                     34                  44
# 1            2                 23                     23                  37
# 2            3                 16                     16                  25
# 3            4                 30                     30                  44
# 4            5                 20                     20                  29
#
#     Image_Metadata_Plate Image_Metadata_Well  \
# 0  localhost220513100001                 A09
# 1  localhost220513100001                 A09
# 2  localhost220513100001                 A09
# 3  localhost220513100001                 A09
# 4  localhost220513100001                 A09
#
#    Image_ImageQuality_Correlation_Actin_20  \
# 0                                 0.237135
# 1                                 0.429162
# 2                                 0.628649
# 3                                 0.292559
# 4                                 0.274312
#
#    Image_ImageQuality_Correlation_ER_20  \
# 0                              0.465877
# 1                              0.489337
# 2                              0.552359
# 3                              0.397774
# 4                              0.462670
#
#    Image_ImageQuality_Correlation_Golgi_20  \
# 0                                 0.431789
# 1                                 0.697063
# 2                                 0.477154
# 3                                 0.350588
# 4                                 0.487833
#
#    Image_ImageQuality_Correlation_Hoechst_20  ...  \
# 0                                   0.240001  ...
# 1                                   0.417105  ...
# 2                                   0.482263  ...
# 3                                   0.313631  ...
# 4                                   0.384392  ...
#
#    Image_ImageQuality_PowerLogLogSlope_Actin  \
# 0                                  -1.334364
# 1                                  -1.652742
# 2                                  -1.670223
# 3                                  -1.418383
# 4                                  -1.379144
#
#    Image_ImageQuality_PowerLogLogSlope_ER  \
# 0                               -2.108479
# 1                               -2.600385
# 2                               -2.762701
# 3                               -2.170335
# 4                               -2.261329
#
#    Image_ImageQuality_PowerLogLogSlope_Golgi  \
# 0                                  -2.053092
# 1                                  -2.600577
# 2                                  -2.558045
# 3                                  -2.142809
# 4                                  -2.368629
#
#    Image_ImageQuality_PowerLogLogSlope_Hoechst  \
# 0                                    -1.888484
# 1                                    -2.806157
# 2                                    -2.768658
# 3                                    -2.207902
# 4                                    -1.815138
#
#    Image_ImageQuality_PowerLogLogSlope_Mitochondria  \
# 0                                         -1.908435
# 1                                         -2.199330
# 2                                         -2.280276
# 3                                         -2.006711
# 4                                         -2.082494
#
#    Image_ImageQuality_Scaling_Actin  Image_ImageQuality_Scaling_ER  \
# 0                             255.0                          255.0
# 1                             255.0                          255.0
# 2                             255.0                          255.0
# 3                             255.0                          255.0
# 4                             255.0                          255.0
#
#    Image_ImageQuality_Scaling_Golgi  Image_ImageQuality_Scaling_Hoechst  \
# 0                             255.0                               255.0
# 1                             255.0                               255.0
# 2                             255.0                               255.0
# 3                             255.0                               255.0
# 4                             255.0                               255.0
#
#    Image_ImageQuality_Scaling_Mitochondria
# 0                                    255.0
# 1                                    255.0
# 2                                    255.0
# 3                                    255.0
# 4                                    255.0
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Merge platemap metadata with extracted image features and image quality

# %%
## Uses pycytominer annotate functionality to merge the platemap and image features and reorder the dataframe
image_features_df = annotate(
    profiles=image_features_df,
    platemap=platemap_df,
    join_on=["Metadata_well_position", "Image_Metadata_Well"],
    output_file="none",
)

image_quality_df = annotate(
    profiles=image_quality_df,
    platemap=platemap_df,
    join_on=["Metadata_well_position", "Image_Metadata_Well"],
    output_file="none",
)

# %% [markdown]
# ## Save image features data frame as `csv.gz` file

# %%
# Save image feature data as a csv
output(image_features_df, image_features_output_file)

print(image_features_df.shape)
image_features_df.head()
# Out:
# (512, 516)
#   Metadata_WellRow  Metadata_WellCol  Metadata_heart_number  \
# 0                A                 9                      9
# 1                A                 9                      9
# 2                A                 9                      9
# 3                A                 9                      9
# 4                A                 9                      9
#
#   Metadata_treatment Metadata_dose         Metadata_Plate Metadata_Well  \
# 0             drug_x           5uM  localhost220513100001           A09
# 1             drug_x           5uM  localhost220513100001           A09
# 2             drug_x           5uM  localhost220513100001           A09
# 3             drug_x           5uM  localhost220513100001           A09
# 4             drug_x           5uM  localhost220513100001           A09
#
#    ImageNumber  Image_Count_Cells  Image_Count_Cytoplasm  ...  \
# 0            1                 34                     34  ...
# 1            2                 23                     23  ...
# 2            3                 16                     16  ...
# 3            4                 30                     30  ...
# 4            5                 20                     20  ...
#
#    Image_Texture_Variance_Golgi_3_02_256  \
# 0                              52.706348
# 1                              38.904857
# 2                              38.207461
# 3                              50.203604
# 4                              64.981442
#
#    Image_Texture_Variance_Golgi_3_03_256  \
# 0                              52.749870
# 1                              38.935283
# 2                              38.226081
# 3                              50.256349
# 4                              65.074773
#
#    Image_Texture_Variance_Hoechst_3_00_256  \
# 0                                91.719909
# 1                                60.510194
# 2                                38.139204
# 3                               106.297290
# 4                                56.298831
#
#    Image_Texture_Variance_Hoechst_3_01_256  \
# 0                                91.543430
# 1                                60.549699
# 2                                38.106845
# 3                               106.425268
# 4                                56.222616
#
#    Image_Texture_Variance_Hoechst_3_02_256  \
# 0                                91.470904
# 1                                60.527953
# 2                                38.133159
# 3                               106.365254
# 4                                56.305175
#
#    Image_Texture_Variance_Hoechst_3_03_256  \
# 0                                91.541820
# 1                                60.549702
# 2                                38.106841
# 3                               106.430593
# 4                                56.218610
#
#    Image_Texture_Variance_Mitochondria_3_00_256  \
# 0                                     65.783776
# 1                                     44.818650
# 2                                     50.200080
# 3                                     56.979249
# 4                                     93.277867
#
#    Image_Texture_Variance_Mitochondria_3_01_256  \
# 0                                     65.846346
# 1                                     44.846460
# 2                                     50.285655
# 3                                     57.034142
# 4                                     93.388141
#
#    Image_Texture_Variance_Mitochondria_3_02_256  \
# 0                                     65.777592
# 1                                     44.806184
# 2                                     50.230629
# 3                                     56.989758
# 4                                     93.274971
#
#    Image_Texture_Variance_Mitochondria_3_03_256
# 0                                     65.846211
# 1                                     44.846421
# 2                                     50.285723
# 3                                     57.034399
# 4                                     93.388373
#
# [5 rows x 516 columns]

# %% [markdown]
# ## Save image quality dataframe as `csv.gz` file

# %%
# Save image feature data as a csv
output(image_quality_df, image_quality_output_file)

print(image_quality_df.shape)
image_quality_df.head()
# Out:
# (512, 36)
#   Metadata_WellRow  Metadata_WellCol  Metadata_heart_number  \
# 0                A                 9                      9
# 1                A                 9                      9
# 2                A                 9                      9
# 3                A                 9                      9
# 4                A                 9                      9
#
#   Metadata_treatment Metadata_dose         Metadata_Plate Metadata_Well  \
# 0             drug_x           5uM  localhost220513100001           A09
# 1             drug_x           5uM  localhost220513100001           A09
# 2             drug_x           5uM  localhost220513100001           A09
# 3             drug_x           5uM  localhost220513100001           A09
# 4             drug_x           5uM  localhost220513100001           A09
#
#    ImageNumber  Image_Count_Cells  Image_Count_Cytoplasm  ...  \
# 0            1                 34                     34  ...
# 1            2                 23                     23  ...
# 2            3                 16                     16  ...
# 3            4                 30                     30  ...
# 4            5                 20                     20  ...
#
#    Image_ImageQuality_PowerLogLogSlope_Actin  \
# 0                                  -1.334364
# 1                                  -1.652742
# 2                                  -1.670223
# 3                                  -1.418383
# 4                                  -1.379144
#
#    Image_ImageQuality_PowerLogLogSlope_ER  \
# 0                               -2.108479
# 1                               -2.600385
# 2                               -2.762701
# 3                               -2.170335
# 4                               -2.261329
#
#    Image_ImageQuality_PowerLogLogSlope_Golgi  \
# 0                                  -2.053092
# 1                                  -2.600577
# 2                                  -2.558045
# 3                                  -2.142809
# 4                                  -2.368629
#
#    Image_ImageQuality_PowerLogLogSlope_Hoechst  \
# 0                                    -1.888484
# 1                                    -2.806157
# 2                                    -2.768658
# 3                                    -2.207902
# 4                                    -1.815138
#
#    Image_ImageQuality_PowerLogLogSlope_Mitochondria  \
# 0                                         -1.908435
# 1                                         -2.199330
# 2                                         -2.280276
# 3                                         -2.006711
# 4                                         -2.082494
#
#    Image_ImageQuality_Scaling_Actin  Image_ImageQuality_Scaling_ER  \
# 0                             255.0                          255.0
# 1                             255.0                          255.0
# 2                             255.0                          255.0
# 3                             255.0                          255.0
# 4                             255.0                          255.0
#
#    Image_ImageQuality_Scaling_Golgi  Image_ImageQuality_Scaling_Hoechst  \
# 0                             255.0                               255.0
# 1                             255.0                               255.0
# 2                             255.0                               255.0
# 3                             255.0                               255.0
# 4                             255.0                               255.0
#
#    Image_ImageQuality_Scaling_Mitochondria
# 0                                    255.0
# 1                                    255.0
# 2                                    255.0
# 3                                    255.0
# 4                                    255.0
#
# [5 rows x 36 columns]

# %% [markdown]
# ## View info of the dataframe

# %%
image_features_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 512 entries, 0 to 511
# Columns: 516 entries, Metadata_WellRow to Image_Texture_Variance_Mitochondria_3_03_256
# dtypes: float64(500), int64(11), object(5)
# memory usage: 2.0+ MB

# %%
image_quality_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 512 entries, 0 to 511
# Data columns (total 36 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Metadata_WellRow                                    512 non-null    object
#  1   Metadata_WellCol                                    512 non-null    int64
#  2   Metadata_heart_number                               512 non-null    int64
#  3   Metadata_treatment                                  512 non-null    object
#  4   Metadata_dose                                       512 non-null    object
#  5   Metadata_Plate                                      512 non-null    object
#  6   Metadata_Well                                       512 non-null    object
#  7   ImageNumber                                         512 non-null    int64
#  8   Image_Count_Cells                                   512 non-null    int64
#  9   Image_Count_Cytoplasm                               512 non-null    int64
#  10  Image_Count_Nuclei                                  512 non-null    int64
#  11  Image_ImageQuality_Correlation_Actin_20             512 non-null    float64
#  12  Image_ImageQuality_Correlation_ER_20                512 non-null    float64
#  13  Image_ImageQuality_Correlation_Golgi_20             512 non-null    float64
#  14  Image_ImageQuality_Correlation_Hoechst_20           512 non-null    float64
#  15  Image_ImageQuality_Correlation_Mitochondria_20      512 non-null    float64
#  16  Image_ImageQuality_FocusScore_Actin                 512 non-null    float64
#  17  Image_ImageQuality_FocusScore_ER                    512 non-null    float64
#  18  Image_ImageQuality_FocusScore_Golgi                 512 non-null    float64
#  19  Image_ImageQuality_FocusScore_Hoechst               512 non-null    float64
#  20  Image_ImageQuality_FocusScore_Mitochondria          512 non-null    float64
#  21  Image_ImageQuality_LocalFocusScore_Actin_20         512 non-null    float64
#  22  Image_ImageQuality_LocalFocusScore_ER_20            512 non-null    float64
#  23  Image_ImageQuality_LocalFocusScore_Golgi_20         512 non-null    float64
#  24  Image_ImageQuality_LocalFocusScore_Hoechst_20       512 non-null    float64
#  25  Image_ImageQuality_LocalFocusScore_Mitochondria_20  512 non-null    float64
#  26  Image_ImageQuality_PowerLogLogSlope_Actin           512 non-null    float64
#  27  Image_ImageQuality_PowerLogLogSlope_ER              512 non-null    float64
#  28  Image_ImageQuality_PowerLogLogSlope_Golgi           512 non-null    float64
#  29  Image_ImageQuality_PowerLogLogSlope_Hoechst         512 non-null    float64
#  30  Image_ImageQuality_PowerLogLogSlope_Mitochondria    512 non-null    float64
#  31  Image_ImageQuality_Scaling_Actin                    512 non-null    float64
#  32  Image_ImageQuality_Scaling_ER                       512 non-null    float64
#  33  Image_ImageQuality_Scaling_Golgi                    512 non-null    float64
#  34  Image_ImageQuality_Scaling_Hoechst                  512 non-null    float64
#  35  Image_ImageQuality_Scaling_Mitochondria             512 non-null    float64
# dtypes: float64(25), int64(6), object(5)
# memory usage: 148.0+ KB
