# %% [markdown]
# # Illumination Correction of CFReT Images

# %% [markdown]
# ## Import Libraries

# %%
import sys
import numpy as np
import pathlib
from matplotlib import pyplot as plt
from pathlib import Path
import os
import skimage

# explicit import to PyBaSiC due to not having package support
sys.path.append("./PyBaSiC/")
import pybasic

import importlib

ICutils = importlib.import_module("ICutils")

# %% [markdown]
# ## Perform Illumination Correction on CFReT pilot images
#
# Only one channel (`d0`) was processed in this notebook as an example. All channels are processed using the `illumcorrect-data.ipynb` file

# %%
# Set location of input and output locations
channel_path = pathlib.Path('../0.download-data/Images/')

save_path = pathlib.Path("IC_Corrected_Images")

# Set the file_extension for the images (if applicable)
file_extension = '.TIF'

# Channels to process
channels = ["d0", "d1", "d2", "d3", "d4"]

# Perform illumination correction on each channel seperately using a `for` loop:
for channel in channels:
    # print(channel)
    print("Correcting", channel, "channel images")

    # If you want to output the flatfield and darkfield calculations, then put "output_calc=True".
    # If you would like to overwrite any existing images when running this function, set "overwrite=True"

    ICutils.run_illum_correct(
        channel_path,
        save_path,
        channel=channel,
        output_calc=False,
        file_extension = '.TIF'
    )
# Out:
# Correcting d0 channel images
# 0 / 199
# 10 / 199
# 20 / 199
# 30 / 199
# 40 / 199
# 50 / 199
# 60 / 199
# 70 / 199
# 80 / 199
# 90 / 199
# 100 / 199
# 110 / 199
# 120 / 199
# 130 / 199
# 140 / 199
# 150 / 199
# 160 / 199
# 170 / 199
# 180 / 199
# 190 / 199
# Correcting {'d0'}
# reweighting_iter: 1
# /home/jenna/CFReT_data/1.preprocessing-data/./PyBaSiC/pybasic/tools/inexact_alm_rspca_l1.py:118: RuntimeWarning: divide by zero encountered in double_scalars
#   B1_offset = np.minimum(B1_offset, B1_uplimit / np.mean(W_idct_hat))
# reweighting_iter: 2
# reweighting_iter: 3
# reweighting_iter: 4
# localhost220512140003_A01f00d0_IllumCorrect.tif already exists!
# localhost220512140003_A01f01d0_IllumCorrect.tif already exists!
# localhost220512140003_A01f02d0_IllumCorrect.tif already exists!
# localhost220512140003_A01f03d0_IllumCorrect.tif already exists!
# localhost220512140003_A01f04d0_IllumCorrect.tif already exists!
# localhost220512140003_A01f05d0_IllumCorrect.tif already exists!
# localhost220512140003_A01f06d0_IllumCorrect.tif already exists!
# localhost220512140003_A01f07d0_IllumCorrect.tif already exists!
# localhost220512140003_A01f08d0_IllumCorrect.tif already exists!
# localhost220512140003_A01f09d0_IllumCorrect.tif already exists!
# localhost220512140003_A01f10d0_IllumCorrect.tif already exists!
# localhost220512140003_A01f11d0_IllumCorrect.tif already exists!
# localhost220512140003_A01f12d0_IllumCorrect.tif already exists!
# localhost220512140003_A01f13d0_IllumCorrect.tif already exists!
# localhost220512140003_A01f14d0_IllumCorrect.tif already exists!
# localhost220512140003_A01f15d0_IllumCorrect.tif already exists!
# localhost220512140003_A02f00d0_IllumCorrect.tif already exists!
# localhost220512140003_A02f01d0_IllumCorrect.tif already exists!
# localhost220512140003_A02f02d0_IllumCorrect.tif already exists!
# localhost220512140003_A02f03d0_IllumCorrect.tif already exists!
# localhost220512140003_A02f04d0_IllumCorrect.tif already exists!
# localhost220512140003_A02f05d0_IllumCorrect.tif already exists!
# localhost220512140003_A02f06d0_IllumCorrect.tif already exists!
# localhost220512140003_A02f07d0_IllumCorrect.tif already exists!
# localhost220512140003_A02f08d0_IllumCorrect.tif already exists!
# localhost220512140003_A02f09d0_IllumCorrect.tif already exists!
# localhost220512140003_A02f10d0_IllumCorrect.tif already exists!
# localhost220512140003_A02f11d0_IllumCorrect.tif already exists!
# localhost220512140003_A02f12d0_IllumCorrect.tif already exists!
# localhost220512140003_A02f13d0_IllumCorrect.tif already exists!
# localhost220512140003_A02f14d0_IllumCorrect.tif already exists!
# localhost220512140003_A02f15d0_IllumCorrect.tif already exists!
# localhost220512140003_A03f00d0_IllumCorrect.tif already exists!
# localhost220512140003_A03f01d0_IllumCorrect.tif already exists!
# localhost220512140003_A03f02d0_IllumCorrect.tif already exists!
# localhost220512140003_A03f03d0_IllumCorrect.tif already exists!
# localhost220512140003_A03f04d0_IllumCorrect.tif already exists!
# localhost220512140003_A03f05d0_IllumCorrect.tif already exists!
# localhost220512140003_A03f06d0_IllumCorrect.tif already exists!
# localhost220512140003_A03f07d0_IllumCorrect.tif already exists!
# localhost220512140003_A03f08d0_IllumCorrect.tif already exists!
# localhost220512140003_A03f09d0_IllumCorrect.tif already exists!
# localhost220512140003_A03f10d0_IllumCorrect.tif already exists!
# localhost220512140003_A03f11d0_IllumCorrect.tif already exists!
# localhost220512140003_A03f12d0_IllumCorrect.tif already exists!
# localhost220512140003_A03f13d0_IllumCorrect.tif already exists!
# localhost220512140003_A03f14d0_IllumCorrect.tif already exists!
# localhost220512140003_A03f15d0_IllumCorrect.tif already exists!
# localhost220512140003_A04f00d0_IllumCorrect.tif already exists!
# localhost220512140003_A04f01d0_IllumCorrect.tif already exists!
# localhost220512140003_A04f02d0_IllumCorrect.tif already exists!
# localhost220512140003_A04f03d0_IllumCorrect.tif already exists!
# localhost220512140003_A04f04d0_IllumCorrect.tif already exists!
# localhost220512140003_A04f05d0_IllumCorrect.tif already exists!
# localhost220512140003_A04f06d0_IllumCorrect.tif already exists!
# localhost220512140003_A04f07d0_IllumCorrect.tif already exists!
# localhost220512140003_A04f08d0_IllumCorrect.tif already exists!
# localhost220512140003_A04f09d0_IllumCorrect.tif already exists!
# localhost220512140003_A04f10d0_IllumCorrect.tif already exists!
# localhost220512140003_A04f11d0_IllumCorrect.tif already exists!
# localhost220512140003_A04f12d0_IllumCorrect.tif already exists!
# localhost220512140003_A04f13d0_IllumCorrect.tif already exists!
# localhost220512140003_A04f14d0_IllumCorrect.tif already exists!
# localhost220512140003_A04f15d0_IllumCorrect.tif already exists!
# localhost220512140003_A05f00d0_IllumCorrect.tif already exists!
# localhost220512140003_A05f01d0_IllumCorrect.tif already exists!
# localhost220512140003_A05f02d0_IllumCorrect.tif already exists!
# localhost220512140003_A05f03d0_IllumCorrect.tif already exists!
# localhost220512140003_A05f04d0_IllumCorrect.tif already exists!
# localhost220512140003_A05f05d0_IllumCorrect.tif already exists!
# localhost220512140003_A05f06d0_IllumCorrect.tif already exists!
# localhost220512140003_A05f07d0_IllumCorrect.tif already exists!
# localhost220512140003_A05f08d0_IllumCorrect.tif already exists!
# localhost220512140003_A05f09d0_IllumCorrect.tif already exists!
# localhost220512140003_A05f10d0_IllumCorrect.tif already exists!
# localhost220512140003_A05f11d0_IllumCorrect.tif already exists!
# localhost220512140003_A05f12d0_IllumCorrect.tif already exists!
# localhost220512140003_A05f13d0_IllumCorrect.tif already exists!
# localhost220512140003_A05f14d0_IllumCorrect.tif already exists!
# localhost220512140003_A05f15d0_IllumCorrect.tif already exists!
# localhost220512140003_A06f00d0_IllumCorrect.tif already exists!
# localhost220512140003_A06f01d0_IllumCorrect.tif already exists!
# localhost220512140003_A06f02d0_IllumCorrect.tif already exists!
# localhost220512140003_A06f03d0_IllumCorrect.tif already exists!
# localhost220512140003_A06f04d0_IllumCorrect.tif already exists!
# localhost220512140003_A06f05d0_IllumCorrect.tif already exists!
# localhost220512140003_A06f06d0_IllumCorrect.tif already exists!
# localhost220512140003_A06f07d0_IllumCorrect.tif already exists!
# localhost220512140003_A06f08d0_IllumCorrect.tif already exists!
# localhost220512140003_A06f09d0_IllumCorrect.tif already exists!
# localhost220512140003_A06f10d0_IllumCorrect.tif already exists!
# localhost220512140003_A06f11d0_IllumCorrect.tif already exists!
# localhost220512140003_A06f12d0_IllumCorrect.tif already exists!
# localhost220512140003_A06f13d0_IllumCorrect.tif already exists!
# localhost220512140003_A06f14d0_IllumCorrect.tif already exists!
# localhost220512140003_A06f15d0_IllumCorrect.tif already exists!
# localhost220512140003_A07f00d0_IllumCorrect.tif already exists!
# localhost220512140003_A07f01d0_IllumCorrect.tif already exists!
# localhost220512140003_A07f02d0_IllumCorrect.tif already exists!
# localhost220512140003_A07f03d0_IllumCorrect.tif already exists!
# localhost220512140003_A07f04d0_IllumCorrect.tif already exists!
# localhost220512140003_A07f05d0_IllumCorrect.tif already exists!
# localhost220512140003_A07f06d0_IllumCorrect.tif already exists!
# localhost220512140003_A07f07d0_IllumCorrect.tif already exists!
# localhost220512140003_A07f08d0_IllumCorrect.tif already exists!
# localhost220512140003_A07f09d0_IllumCorrect.tif already exists!
# localhost220512140003_A07f10d0_IllumCorrect.tif already exists!
# localhost220512140003_A07f11d0_IllumCorrect.tif already exists!
# localhost220512140003_A07f12d0_IllumCorrect.tif already exists!
# localhost220512140003_A07f13d0_IllumCorrect.tif already exists!
# localhost220512140003_A07f14d0_IllumCorrect.tif already exists!
# localhost220512140003_A07f15d0_IllumCorrect.tif already exists!
# localhost220512140003_A08f00d0_IllumCorrect.tif already exists!
# localhost220512140003_A08f01d0_IllumCorrect.tif already exists!
# localhost220512140003_A08f02d0_IllumCorrect.tif already exists!
# localhost220512140003_A08f03d0_IllumCorrect.tif already exists!
# localhost220512140003_A08f04d0_IllumCorrect.tif already exists!
# localhost220512140003_A08f05d0_IllumCorrect.tif already exists!
# localhost220512140003_A08f06d0_IllumCorrect.tif already exists!
# localhost220512140003_A08f07d0_IllumCorrect.tif already exists!
# localhost220512140003_A08f08d0_IllumCorrect.tif already exists!
# localhost220512140003_A08f09d0_IllumCorrect.tif already exists!
# localhost220512140003_A08f10d0_IllumCorrect.tif already exists!
# localhost220512140003_A08f11d0_IllumCorrect.tif already exists!
# localhost220512140003_A08f12d0_IllumCorrect.tif already exists!
# localhost220512140003_A08f13d0_IllumCorrect.tif already exists!
# localhost220512140003_A08f14d0_IllumCorrect.tif already exists!
# localhost220512140003_A08f15d0_IllumCorrect.tif already exists!
# localhost220512140003_B01f00d0_IllumCorrect.tif already exists!
# localhost220512140003_B01f01d0_IllumCorrect.tif already exists!
# localhost220512140003_B01f02d0_IllumCorrect.tif already exists!
# localhost220512140003_B01f03d0_IllumCorrect.tif already exists!
# localhost220512140003_B01f04d0_IllumCorrect.tif already exists!
# localhost220512140003_B01f05d0_IllumCorrect.tif already exists!
# localhost220512140003_B01f06d0_IllumCorrect.tif already exists!
# localhost220512140003_B01f07d0_IllumCorrect.tif already exists!
# localhost220512140003_B01f08d0_IllumCorrect.tif already exists!
# localhost220512140003_B01f09d0_IllumCorrect.tif already exists!
# localhost220512140003_B01f10d0_IllumCorrect.tif already exists!
# localhost220512140003_B01f11d0_IllumCorrect.tif already exists!
# localhost220512140003_B01f12d0_IllumCorrect.tif already exists!
# localhost220512140003_B01f13d0_IllumCorrect.tif already exists!
# localhost220512140003_B01f14d0_IllumCorrect.tif already exists!
# localhost220512140003_B01f15d0_IllumCorrect.tif already exists!
# localhost220512140003_B02f00d0_IllumCorrect.tif already exists!
# localhost220512140003_B02f01d0_IllumCorrect.tif already exists!
# localhost220512140003_B02f02d0_IllumCorrect.tif already exists!
# localhost220512140003_B02f03d0_IllumCorrect.tif already exists!
# localhost220512140003_B02f04d0_IllumCorrect.tif already exists!
# localhost220512140003_B02f05d0_IllumCorrect.tif already exists!
# localhost220512140003_B02f06d0_IllumCorrect.tif already exists!
# localhost220512140003_B02f07d0_IllumCorrect.tif already exists!
# localhost220512140003_B02f08d0_IllumCorrect.tif already exists!
# localhost220512140003_B02f09d0_IllumCorrect.tif already exists!
# localhost220512140003_B02f10d0_IllumCorrect.tif already exists!
# localhost220512140003_B02f11d0_IllumCorrect.tif already exists!
# localhost220512140003_B02f12d0_IllumCorrect.tif already exists!
# localhost220512140003_B02f13d0_IllumCorrect.tif already exists!
# localhost220512140003_B02f14d0_IllumCorrect.tif already exists!
# localhost220512140003_B02f15d0_IllumCorrect.tif already exists!
# localhost220512140003_B03f00d0_IllumCorrect.tif already exists!
# localhost220512140003_B03f01d0_IllumCorrect.tif already exists!
# localhost220512140003_B03f02d0_IllumCorrect.tif already exists!
# localhost220512140003_B03f03d0_IllumCorrect.tif already exists!
# localhost220512140003_B03f04d0_IllumCorrect.tif already exists!
# localhost220512140003_B03f05d0_IllumCorrect.tif already exists!
# localhost220512140003_B03f06d0_IllumCorrect.tif already exists!
# localhost220512140003_B03f07d0_IllumCorrect.tif already exists!
# localhost220512140003_B03f08d0_IllumCorrect.tif already exists!
# localhost220512140003_B03f09d0_IllumCorrect.tif already exists!
# localhost220512140003_B03f10d0_IllumCorrect.tif already exists!
# localhost220512140003_B03f11d0_IllumCorrect.tif already exists!
# localhost220512140003_B03f12d0_IllumCorrect.tif already exists!
# localhost220512140003_B03f13d0_IllumCorrect.tif already exists!
# localhost220512140003_B03f14d0_IllumCorrect.tif already exists!
# localhost220512140003_B03f15d0_IllumCorrect.tif already exists!
# localhost220512140003_B04f00d0_IllumCorrect.tif already exists!
# localhost220512140003_B04f01d0_IllumCorrect.tif already exists!
# localhost220512140003_B04f02d0_IllumCorrect.tif already exists!
# localhost220512140003_B04f03d0_IllumCorrect.tif already exists!
# localhost220512140003_B04f04d0_IllumCorrect.tif already exists!
# localhost220512140003_B04f05d0_IllumCorrect.tif already exists!
# localhost220512140003_B04f06d0_IllumCorrect.tif already exists!
# localhost220512140003_B04f07d0_IllumCorrect.tif already exists!
# localhost220512140003_B04f08d0_IllumCorrect.tif already exists!
# localhost220512140003_B04f09d0_IllumCorrect.tif already exists!
# localhost220512140003_B04f10d0_IllumCorrect.tif already exists!
# localhost220512140003_B04f11d0_IllumCorrect.tif already exists!
# localhost220512140003_B04f12d0_IllumCorrect.tif already exists!
# localhost220512140003_B04f13d0_IllumCorrect.tif already exists!
# localhost220512140003_B04f14d0_IllumCorrect.tif already exists!
# localhost220512140003_B04f15d0_IllumCorrect.tif already exists!
# localhost220512140003_B05f00d0_IllumCorrect.tif already exists!
# localhost220512140003_B05f01d0_IllumCorrect.tif already exists!
# localhost220512140003_B05f02d0_IllumCorrect.tif already exists!
# localhost220512140003_B05f03d0_IllumCorrect.tif already exists!
# localhost220512140003_B05f04d0_IllumCorrect.tif already exists!
# localhost220512140003_B05f05d0_IllumCorrect.tif already exists!
# localhost220512140003_B05f06d0_IllumCorrect.tif already exists!
# Correcting d1 channel images
# 0 / 198
# 10 / 198
# 20 / 198
# 30 / 198
# 40 / 198
# 50 / 198
# 60 / 198
# 70 / 198
# 80 / 198
# 90 / 198
# 100 / 198
# 110 / 198
# 120 / 198
# 130 / 198
# 140 / 198
# 150 / 198
# 160 / 198
# 170 / 198
# 180 / 198
# 190 / 198
# Correcting {'d1'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/jenna/CFReT_data/1.preprocessing-data/illumcorrect-data.ipynb Cell 5 in <cell line: 13>()
#      <a href='vscode-notebook-cell:/home/jenna/CFReT_data/1.preprocessing-data/illumcorrect-data.ipynb#W4sZmlsZQ%3D%3D?line=14'>15</a> print("Correcting", channel, "channel images")
#      <a href='vscode-notebook-cell:/home/jenna/CFReT_data/1.preprocessing-data/illumcorrect-data.ipynb#W4sZmlsZQ%3D%3D?line=16'>17</a> # If you want to output the flatfield and darkfield calculations, then put "output_calc=True".
#      <a href='vscode-notebook-cell:/home/jenna/CFReT_data/1.preprocessing-data/illumcorrect-data.ipynb#W4sZmlsZQ%3D%3D?line=17'>18</a> # If you would like to overwrite any existing images when running this function, set "overwrite=True"
# ---> <a href='vscode-notebook-cell:/home/jenna/CFReT_data/1.preprocessing-data/illumcorrect-data.ipynb#W4sZmlsZQ%3D%3D?line=19'>20</a> ICutils.run_illum_correct(
#      <a href='vscode-notebook-cell:/home/jenna/CFReT_data/1.preprocessing-data/illumcorrect-data.ipynb#W4sZmlsZQ%3D%3D?line=20'>21</a>     channel_path,
#      <a href='vscode-notebook-cell:/home/jenna/CFReT_data/1.preprocessing-data/illumcorrect-data.ipynb#W4sZmlsZQ%3D%3D?line=21'>22</a>     save_path,
#      <a href='vscode-notebook-cell:/home/jenna/CFReT_data/1.preprocessing-data/illumcorrect-data.ipynb#W4sZmlsZQ%3D%3D?line=22'>23</a>     channel=channel,
#      <a href='vscode-notebook-cell:/home/jenna/CFReT_data/1.preprocessing-data/illumcorrect-data.ipynb#W4sZmlsZQ%3D%3D?line=23'>24</a>     output_calc=False,
#      <a href='vscode-notebook-cell:/home/jenna/CFReT_data/1.preprocessing-data/illumcorrect-data.ipynb#W4sZmlsZQ%3D%3D?line=24'>25</a>     file_extension = '.TIF'
#      <a href='vscode-notebook-cell:/home/jenna/CFReT_data/1.preprocessing-data/illumcorrect-data.ipynb#W4sZmlsZQ%3D%3D?line=25'>26</a> )
#
# File ~/CFReT_data/1.preprocessing-data/ICutils.py:88, in run_illum_correct(channel_path, save_path, channel, output_calc, file_extension, overwrite)
#      84 images, image_names = load_pybasic_data(channel_path, channel, file_extension)
#      86 print("Correcting", {channel})
# ---> 88 flatfield, darkfield = pybasic.basic(images, darkfield=True)
#      90 # Optional output that displays the plots for the flatfield and darkfield calculations if set to True (default is False)
#      91 if output_calc == True:
#
# File ~/CFReT_data/1.preprocessing-data/./PyBaSiC/pybasic/_background.py:172, in basic(images_list, segmentation, verbosity, **kwargs)
#     168 nrows = ncols = _working_size = settings.working_size
#     170 _saved_size = images_list[0].shape
# --> 172 D = np.dstack(_resize_images_list(images_list=images_list, side_size=_working_size))
#     174 meanD = np.mean(D, axis=2)
#     175 meanD = meanD / np.mean(meanD)
#
# File ~/CFReT_data/1.preprocessing-data/./PyBaSiC/pybasic/tools/_resize.py:15, in _resize_images_list(images_list, side_size, x_side_size, y_side_size)
#      13 for i, im in enumerate(images_list):
#      14     if im.shape[0] != x_side_size or im.shape[1] != y_side_size:
# ---> 15         resized_images_list.append(skresize(
#      16             im,
#      17             (x_side_size, y_side_size),
#      18             order = RESIZE_ORDER,
#      19             mode = RESIZE_MODE,
#      20             preserve_range = _preserve_range
#      21             )
#      22         )
#      23     else:
#      24         resized_images_list.append(im)
#
# File ~/anaconda3/lib/python3.9/site-packages/skimage/transform/_warps.py:181, in resize(image, output_shape, order, mode, cval, clip, preserve_range, anti_aliasing, anti_aliasing_sigma)
#     178         elif np.any((anti_aliasing_sigma > 0) & (factors <= 1)):
#     179             warn("Anti-aliasing standard deviation greater than zero but "
#     180                  "not down-sampling along all axes")
# --> 181     image = ndi.gaussian_filter(image, anti_aliasing_sigma,
#     182                                 cval=cval, mode=ndi_mode)
#     184 if NumpyVersion(scipy.__version__) >= '1.6.0':
#     185     # The grid_mode kwarg was introduced in SciPy 1.6.0
#     186     zoom_factors = [1 / f for f in factors]
#
# File ~/anaconda3/lib/python3.9/site-packages/scipy/ndimage/filters.py:342, in gaussian_filter(input, sigma, order, output, mode, cval, truncate)
#     340 if len(axes) > 0:
#     341     for axis, sigma, order, mode in axes:
# --> 342         gaussian_filter1d(input, sigma, axis, order, output,
#     343                           mode, cval, truncate)
#     344         input = output
#     345 else:
#
# File ~/anaconda3/lib/python3.9/site-packages/scipy/ndimage/filters.py:261, in gaussian_filter1d(input, sigma, axis, order, output, mode, cval, truncate)
#     259 # Since we are calling correlate, not convolve, revert the kernel
#     260 weights = _gaussian_kernel1d(sigma, order, lw)[::-1]
# --> 261 return correlate1d(input, weights, axis, output, mode, cval, 0)
#
# File ~/anaconda3/lib/python3.9/site-packages/scipy/ndimage/filters.py:133, in correlate1d(input, weights, axis, output, mode, cval, origin)
#     129     raise ValueError('Invalid origin; origin must satisfy '
#     130                      '-(len(weights) // 2) <= origin <= '
#     131                      '(len(weights)-1) // 2')
#     132 mode = _ni_support._extend_mode_to_code(mode)
# --> 133 _nd_image.correlate1d(input, weights, axis, output, mode, cval,
#     134                       origin)
#     135 return output
#
# KeyboardInterrupt:
