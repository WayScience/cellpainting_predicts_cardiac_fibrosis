# %% [markdown]
# # Find single cell images based on UMAP coordinates

# %% [markdown]
# ## Import libraries

# %%
import pathlib
import pandas as pd
from PIL import Image
import cv2
import os
import numpy as np
import tifffile as tf
import yaml
import pprint

# %% [markdown]
# ## Set variables and paths

# %%
# Load in UMAP + metadata for each single cell as data frame
UMAP_plate3_df = pd.read_csv(
    pathlib.Path("./results/UMAP_localhost230405150001_sc_feature_selected.tsv.gz"), sep="\t"
)
print(UMAP_plate3_df.shape)

# Images directory for plate 3
images_dir = pathlib.Path(
    "../../../1.preprocessing_data/Corrected_Images/localhost230405150001/"
).resolve(strict=True)

# Output dir for composite and cropped images
output_img_dir = pathlib.Path("./images")
output_img_dir.mkdir(exist_ok=True)

# Output dirs 
comp_dir = pathlib.Path("./images/composite_imgs")
comp_dir.mkdir(exist_ok=True)
crop_dir = pathlib.Path("./images/cropped_imgs")
crop_dir.mkdir(exist_ok=True)

# CSV file path to store the data
csv_file_path = "random_rows_for_UMAP.csv"

# Check if the CSV file already exists
if os.path.isfile(csv_file_path):
    # Load the existing CSV into a DataFrame
    df = pd.read_csv(csv_file_path)
else:
    # Create a new DataFrame if the CSV doesn't exist
    df = pd.DataFrame(
        columns=[
            "Metadata_cell_type",
            "Metadata_treatment",
            "Metadata_Plate",
            "Metadata_Well",
            "Metadata_Site",
            "Metadata_Cells_Location_Center_X",
            "Metadata_Cells_Location_Center_Y",
            "UMAP0",
            "UMAP1",
        ]
    )
# Out:
# (26992, 19)

# %% [markdown]
# ## Read in `yaml` file with settings for each single cell type

# %%
# load in plate information
dictionary_path = pathlib.Path("./image_settings.yaml")
with open(dictionary_path) as file:
    cell_info_dictionary = yaml.load(file, Loader=yaml.FullLoader)

# view the dictionary to assess that all info is added correctly
pprint.pprint(cell_info_dictionary, indent=4)
# Out:
# {   'failing-DMSO-bottom': {   'Random state': 30,
#                                'UMAP0': [-1, 1],
#                                'UMAP1': [-2, 1],
#                                'composite_save_path': 'composite_image_failing_DMSO_bottom.tiff',
#                                'crop_save_path': 'cell_cropped_failing_DMSO_bottom.tiff'},
#     'failing-DMSO-left': {   'Random state': 30,
#                              'UMAP0': [-3, 0],
#                              'UMAP1': [2.5, 5],
#                              'composite_save_path': 'composite_image_failing_DMSO_left.tiff',
#                              'crop_save_path': 'cell_cropped_failing_DMSO_left.tiff'},
#     'failing-DMSO-left1': {   'Random state': 65,
#                               'UMAP0': [-3, 0],
#                               'UMAP1': [2.5, 5],
#                               'composite_save_path': 'composite_image_failing_DMSO_left1.tiff',
#                               'crop_save_path': 'cell_cropped_failing_DMSO_left1.tiff'},
#     'failing-DMSO-left2': {   'Random state': 12,
#                               'UMAP0': [-3, 0],
#                               'UMAP1': [2.5, 5],
#                               'composite_save_path': 'composite_image_failing_DMSO_left2.tiff',
#                               'crop_save_path': 'cell_cropped_failing_DMSO_left2.tiff'},
#     'failing-DMSO-right': {   'Random state': 30,
#                               'UMAP0': [6, 7],
#                               'UMAP1': [3.75, 5],
#                               'composite_save_path': 'composite_image_failing_DMSO_right.tiff',
#                               'crop_save_path': 'cell_cropped_failing_DMSO_right.tiff'},
#     'failing-drug_x-bottom': {   'Random state': 30,
#                                  'UMAP0': [-1, 1],
#                                  'UMAP1': [-2, 1],
#                                  'composite_save_path': 'composite_image_failing_drug_x_bottom.tiff',
#                                  'crop_save_path': 'cell_cropped_failing_drug_x_bottom.tiff'},
#     'failing-drug_x-left': {   'Random state': 30,
#                                'UMAP0': [-1, 0],
#                                'UMAP1': [6.25, 7.5],
#                                'composite_save_path': 'composite_image_failing_drug_x_left.tiff',
#                                'crop_save_path': 'cell_cropped_failing_drug_x_left.tiff'},
#     'failing-drug_x-left1': {   'Random state': 8,
#                                 'UMAP0': [-1, 0],
#                                 'UMAP1': [6.25, 7.5],
#                                 'composite_save_path': 'composite_image_failing_drug_x_left1.tiff',
#                                 'crop_save_path': 'cell_cropped_failing_drug_x_left1.tiff'},
#     'failing-drug_x-left2': {   'Random state': 75,
#                                 'UMAP0': [-1, 0],
#                                 'UMAP1': [6.25, 7.5],
#                                 'composite_save_path': 'composite_image_failing_drug_x_left2.tiff',
#                                 'crop_save_path': 'cell_cropped_failing_drug_x_left2.tiff'},
#     'failing-drug_x-right': {   'Random state': 15,
#                                 'UMAP0': [6, 7.5],
#                                 'UMAP1': [3.75, 4.5],
#                                 'composite_save_path': 'composite_image_failing_drug_x_right.tiff',
#                                 'crop_save_path': 'cell_cropped_failing_drug_x_right.tiff'},
#     'healthy-DMSO-bottom': {   'Random state': 25,
#                                'UMAP0': [-1, 1],
#                                'UMAP1': [-2, 1],
#                                'composite_save_path': 'composite_image_healthy_DMSO_bottom.tiff',
#                                'crop_save_path': 'cell_cropped_healthy_DMSO_bottom.tiff'},
#     'healthy-DMSO-right': {   'Random state': 25,
#                               'UMAP0': [6, 7.5],
#                               'UMAP1': [3.5, 4.5],
#                               'composite_save_path': 'composite_image_healthy_DMSO_right.tiff',
#                               'crop_save_path': 'cell_cropped_healthy_DMSO_right.tiff'},
#     'healthy-DMSO-top': {   'Random state': 15,
#                             'UMAP0': [0.5, 2],
#                             'UMAP1': [8.5, 9],
#                             'composite_save_path': 'composite_image_healthy_DMSO_top.tiff',
#                             'crop_save_path': 'cell_cropped_healthy_DMSO_top.tiff'},
#     'healthy-DMSO-top1': {   'Random state': 37,
#                              'UMAP0': [0.5, 2],
#                              'UMAP1': [8.5, 9],
#                              'composite_save_path': 'composite_image_healthy_DMSO_top1.tiff',
#                              'crop_save_path': 'cell_cropped_healthy_DMSO_top1.tiff'},
#     'healthy-DMSO-top2': {   'Random state': 56,
#                              'UMAP0': [0.5, 2],
#                              'UMAP1': [8.5, 9],
#                              'composite_save_path': 'composite_image_healthy_DMSO_top2.tiff',
#                              'crop_save_path': 'cell_cropped_healthy_DMSO_top2.tiff'}}

# %% [markdown]
# ## Find single cells from each cell type and treatment from UMAP (plate 3)

# %%
for crop_cell, info in cell_info_dictionary.items():
    # Define your filter conditions
    condition = (
        (UMAP_plate3_df['Metadata_cell_type'] == crop_cell.split('-')[0]) &
        (UMAP_plate3_df['Metadata_treatment'] == crop_cell.split('-')[1]) &
        (UMAP_plate3_df['UMAP0'].between(info["UMAP0"][0], info["UMAP0"][1]) &
        (UMAP_plate3_df['UMAP1'].between(info["UMAP1"][0], info["UMAP1"][1]))
    ))

    # Apply the filter
    filtered_df = UMAP_plate3_df[condition]

    # Apply the filter
    filtered_df = UMAP_plate3_df[condition]

    # Select and display only the specific columns
    selected_columns = [
        'Metadata_cell_type',
        'Metadata_treatment',
        'Metadata_Plate',
        'Metadata_Well',
        'Metadata_Site',
        'Metadata_Cells_Location_Center_X',
        'Metadata_Cells_Location_Center_Y',
        'UMAP0',
        'UMAP1'
    ]

    filtered_df = filtered_df[selected_columns]

    # Randomly select a row
    random_row = filtered_df.sample(n=1, random_state=info["Random state"])  

    # Add the selected row to the DataFrame
    df = df.append(random_row, ignore_index=True)

    # Assign the direction to the UMAP_direction column for the last added row
    df.at[df.index[-1], "UMAP_direction"] = crop_cell.split('-')[2]

    # Save the updated DataFrame to the CSV file
    df.to_csv(csv_file_path, index=False)

    # Create a filename based on Metadata_Plate, Metadata_Well, Metadata_Site
    plate = random_row['Metadata_Plate'].values[0]
    well = random_row['Metadata_Well'].values[0]
    site = random_row['Metadata_Site'].values[0]

    # Initialize a list to store file paths
    file_paths = []

    # Create 5 different file paths with "d0" through "d4" suffixes
    for i in range(5):
        filename = f"{images_dir}/{plate}_{well}{site}d{i}_illumcorrect.tiff"
        file_paths.append(filename)

    print("Randomly selected row:")
    print(random_row)
    print("Generated filenames:")
    for path in file_paths:
        print(path)

    # Initialize empty lists to store the images for each channel
    blue_channel = []
    green_channel = []
    red_channel = []

    # Iterate over files in the directory
    for file_path in file_paths:
        filename = pathlib.Path(file_path).name
        if 'd0' in filename:
            blue_channel_image = cv2.imread(str(file_path), cv2.IMREAD_UNCHANGED)
            blue_channel.append(blue_channel_image)
        elif 'd1' in filename:
            green_channel_image = cv2.imread(str(file_path), cv2.IMREAD_UNCHANGED)
            green_channel.append(green_channel_image)
        elif 'd4' in filename:
            red_channel_image = cv2.imread(str(file_path), cv2.IMREAD_UNCHANGED)
            red_channel.append(red_channel_image)

    # Stack the images for each channel along the channel axis
    blue_channel_stack = np.stack(blue_channel, axis=-1)
    green_channel_stack = np.stack(green_channel, axis=-1)
    red_channel_stack = np.stack(red_channel, axis=-1)

    # Scale the pixel values to fit within the 16-bit range (0-65535)
    blue_channel_stack = (blue_channel_stack / np.max(blue_channel_stack) * 65535).astype(np.uint16)
    green_channel_stack = (green_channel_stack / np.max(green_channel_stack) * 65535).astype(np.uint16)
    red_channel_stack = (red_channel_stack / np.max(red_channel_stack) * 65535).astype(np.uint16)

    # Create the RGB image by merging the channels
    composite_image = cv2.merge((red_channel_stack, green_channel_stack, blue_channel_stack)).astype(np.uint16)

    # Path for saving comp images
    comp_path = pathlib.Path(f"{comp_dir}/{info['composite_save_path']}")

    # Save the composite 16-bit RGB tiff image
    tf.imwrite(comp_path, composite_image)

    # Load the composite image
    composite_image = Image.open(comp_path)

    # Assuming you have a DataFrame called "filtered_df" with center coordinates
    center_x = random_row["Metadata_Cells_Location_Center_X"]
    center_y = random_row["Metadata_Cells_Location_Center_Y"]

    # Define the size of the cropping box (128x128 pixels)
    box_size = 250

    # Paths for saving cropped images
    crop_path = pathlib.Path(f"{crop_dir}/{info['crop_save_path']}")

    # Iterate through the center coordinates and crop each cell
    for x, y in zip(center_x, center_y):
        left = x - box_size // 2
        top = y - box_size // 2
        right = x + box_size // 2
        bottom = y + box_size // 2

        # Crop the cell
        cell_image = composite_image.crop((left, top, right, bottom))

        # Save the cropped cell image with a unique name, you can use the cell's ID or index
        cell_image.save(crop_path)

    # Close the composite image
    composite_image.close()
# Out:
# Randomly selected row:
#      Metadata_cell_type Metadata_treatment         Metadata_Plate  \
# 4294            failing               DMSO  localhost230405150001
#
#      Metadata_Well Metadata_Site  Metadata_Cells_Location_Center_X  \
# 4294           B08           f11                        800.286004
#
#       Metadata_Cells_Location_Center_Y     UMAP0     UMAP1
# 4294                        925.841785  6.514684  4.891298
# Generated filenames:
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_B08f11d0_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_B08f11d1_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_B08f11d2_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_B08f11d3_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_B08f11d4_illumcorrect.tiff
# Randomly selected row:
#       Metadata_cell_type Metadata_treatment         Metadata_Plate  \
# 19532            healthy               DMSO  localhost230405150001
#
#       Metadata_Well Metadata_Site  Metadata_Cells_Location_Center_X  \
# 19532           E08           f14                        618.375881
#
#        Metadata_Cells_Location_Center_Y     UMAP0     UMAP1
# 19532                        343.740505  1.320012  8.948556
# Generated filenames:
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_E08f14d0_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_E08f14d1_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_E08f14d2_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_E08f14d3_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_E08f14d4_illumcorrect.tiff
# Randomly selected row:
#      Metadata_cell_type Metadata_treatment         Metadata_Plate  \
# 5796            healthy               DMSO  localhost230405150001
#
#      Metadata_Well Metadata_Site  Metadata_Cells_Location_Center_X  \
# 5796           C02           f00                        636.211009
#
#       Metadata_Cells_Location_Center_Y     UMAP0     UMAP1
# 5796                        674.271667  0.857913  8.796428
# Generated filenames:
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_C02f00d0_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_C02f00d1_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_C02f00d2_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_C02f00d3_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_C02f00d4_illumcorrect.tiff
# Randomly selected row:
#      Metadata_cell_type Metadata_treatment         Metadata_Plate  \
# 5848            healthy               DMSO  localhost230405150001
#
#      Metadata_Well Metadata_Site  Metadata_Cells_Location_Center_X  \
# 5848           C02           f04                        612.669098
#
#       Metadata_Cells_Location_Center_Y     UMAP0     UMAP1
# 5848                        518.381259  0.864751  8.943674
# Generated filenames:
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_C02f04d0_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_C02f04d1_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_C02f04d2_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_C02f04d3_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_C02f04d4_illumcorrect.tiff
# /tmp/ipykernel_2235774/1070493191.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(random_row, ignore_index=True)
# /tmp/ipykernel_2235774/1070493191.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(random_row, ignore_index=True)
# /tmp/ipykernel_2235774/1070493191.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(random_row, ignore_index=True)
# /tmp/ipykernel_2235774/1070493191.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(random_row, ignore_index=True)
# /tmp/ipykernel_2235774/1070493191.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(random_row, ignore_index=True)
# Randomly selected row:
#      Metadata_cell_type Metadata_treatment         Metadata_Plate  \
# 4323            failing             drug_x  localhost230405150001
#
#      Metadata_Well Metadata_Site  Metadata_Cells_Location_Center_X  \
# 4323           B09           f00                        884.790396
#
#       Metadata_Cells_Location_Center_Y     UMAP0     UMAP1
# 4323                        437.272104  7.089754  4.438821
# Generated filenames:
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_B09f00d0_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_B09f00d1_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_B09f00d2_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_B09f00d3_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_B09f00d4_illumcorrect.tiff
# Randomly selected row:
#       Metadata_cell_type Metadata_treatment         Metadata_Plate  \
# 19509            healthy               DMSO  localhost230405150001
#
#       Metadata_Well Metadata_Site  Metadata_Cells_Location_Center_X  \
# 19509           E08           f13                        551.964247
#
#        Metadata_Cells_Location_Center_Y     UMAP0     UMAP1
# 19509                        488.344529  7.230323  3.538924
# Generated filenames:
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_E08f13d0_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_E08f13d1_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_E08f13d2_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_E08f13d3_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_E08f13d4_illumcorrect.tiff
# Randomly selected row:
#      Metadata_cell_type Metadata_treatment         Metadata_Plate  \
# 4929            failing             drug_x  localhost230405150001
#
#      Metadata_Well Metadata_Site  Metadata_Cells_Location_Center_X  \
# 4929           B09           f14                        843.208391
#
#       Metadata_Cells_Location_Center_Y     UMAP0     UMAP1
# 4929                        795.094622 -0.125942  6.425529
# Generated filenames:
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_B09f14d0_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_B09f14d1_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_B09f14d2_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_B09f14d3_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_B09f14d4_illumcorrect.tiff
# Randomly selected row:
#      Metadata_cell_type Metadata_treatment         Metadata_Plate  \
# 4648            failing             drug_x  localhost230405150001
#
#      Metadata_Well Metadata_Site  Metadata_Cells_Location_Center_X  \
# 4648           B09           f12                         575.97204
#
#       Metadata_Cells_Location_Center_Y     UMAP0     UMAP1
# 4648                        793.422934 -0.142003  6.976597
# Generated filenames:
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_B09f12d0_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_B09f12d1_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_B09f12d2_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_B09f12d3_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_B09f12d4_illumcorrect.tiff
# Randomly selected row:
#      Metadata_cell_type Metadata_treatment         Metadata_Plate  \
# 4614            failing             drug_x  localhost230405150001
#
#      Metadata_Well Metadata_Site  Metadata_Cells_Location_Center_X  \
# 4614           B09           f11                        185.834468
#
#       Metadata_Cells_Location_Center_Y     UMAP0     UMAP1
# 4614                        439.654439 -0.329019  6.950427
# Generated filenames:
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_B09f11d0_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_B09f11d1_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_B09f11d2_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_B09f11d3_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_B09f11d4_illumcorrect.tiff
# Randomly selected row:
#       Metadata_cell_type Metadata_treatment         Metadata_Plate  \
# 15772            failing               DMSO  localhost230405150001
#
#       Metadata_Well Metadata_Site  Metadata_Cells_Location_Center_X  \
# 15772           D08           f11                        599.850744
#
#        Metadata_Cells_Location_Center_Y     UMAP0     UMAP1
# 15772                        366.300584 -2.100151  3.603169
# Generated filenames:
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_D08f11d0_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_D08f11d1_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_D08f11d2_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_D08f11d3_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_D08f11d4_illumcorrect.tiff
# /tmp/ipykernel_2235774/1070493191.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(random_row, ignore_index=True)
# /tmp/ipykernel_2235774/1070493191.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(random_row, ignore_index=True)
# /tmp/ipykernel_2235774/1070493191.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(random_row, ignore_index=True)
# /tmp/ipykernel_2235774/1070493191.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(random_row, ignore_index=True)
# /tmp/ipykernel_2235774/1070493191.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(random_row, ignore_index=True)
# /tmp/ipykernel_2235774/1070493191.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(random_row, ignore_index=True)
# Randomly selected row:
#       Metadata_cell_type Metadata_treatment         Metadata_Plate  \
# 24443            failing               DMSO  localhost230405150001
#
#       Metadata_Well Metadata_Site  Metadata_Cells_Location_Center_X  \
# 24443           G07           f14                        679.710652
#
#        Metadata_Cells_Location_Center_Y     UMAP0     UMAP1
# 24443                        733.283292 -1.517728  3.149721
# Generated filenames:
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_G07f14d0_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_G07f14d1_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_G07f14d2_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_G07f14d3_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_G07f14d4_illumcorrect.tiff
# Randomly selected row:
#       Metadata_cell_type Metadata_treatment         Metadata_Plate  \
# 21344            failing               DMSO  localhost230405150001
#
#       Metadata_Well Metadata_Site  Metadata_Cells_Location_Center_X  \
# 21344           G03           f09                        472.665133
#
#        Metadata_Cells_Location_Center_Y     UMAP0     UMAP1
# 21344                        801.599422 -2.285524  2.529616
# Generated filenames:
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_G03f09d0_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_G03f09d1_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_G03f09d2_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_G03f09d3_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_G03f09d4_illumcorrect.tiff
# Randomly selected row:
#       Metadata_cell_type Metadata_treatment         Metadata_Plate  \
# 25737            failing               DMSO  localhost230405150001
#
#       Metadata_Well Metadata_Site  Metadata_Cells_Location_Center_X  \
# 25737           G09           f12                        151.949074
#
#        Metadata_Cells_Location_Center_Y     UMAP0     UMAP1
# 25737                        403.410403 -0.820053 -0.268939
# Generated filenames:
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_G09f12d0_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_G09f12d1_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_G09f12d2_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_G09f12d3_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_G09f12d4_illumcorrect.tiff
# Randomly selected row:
#      Metadata_cell_type Metadata_treatment         Metadata_Plate  \
# 2626            failing             drug_x  localhost230405150001
#
#      Metadata_Well Metadata_Site  Metadata_Cells_Location_Center_X  \
# 2626           B06           f08                        840.570162
#
#       Metadata_Cells_Location_Center_Y    UMAP0     UMAP1
# 2626                        267.272611  0.87921  0.801787
# Generated filenames:
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_B06f08d0_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_B06f08d1_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_B06f08d2_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_B06f08d3_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_B06f08d4_illumcorrect.tiff
# Randomly selected row:
#      Metadata_cell_type Metadata_treatment         Metadata_Plate  \
# 7460            healthy               DMSO  localhost230405150001
#
#      Metadata_Well Metadata_Site  Metadata_Cells_Location_Center_X  \
# 7460           C05           f15                        367.876069
#
#       Metadata_Cells_Location_Center_Y     UMAP0     UMAP1
# 7460                        202.011329  0.881017 -0.473348
# Generated filenames:
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_C05f15d0_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_C05f15d1_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_C05f15d2_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_C05f15d3_illumcorrect.tiff
# /home/jenna/CFReT_data/1.preprocessing_data/Corrected_Images/localhost230405150001/localhost230405150001_C05f15d4_illumcorrect.tiff
# /tmp/ipykernel_2235774/1070493191.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(random_row, ignore_index=True)
# /tmp/ipykernel_2235774/1070493191.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(random_row, ignore_index=True)
# /tmp/ipykernel_2235774/1070493191.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(random_row, ignore_index=True)
# /tmp/ipykernel_2235774/1070493191.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(random_row, ignore_index=True)
